# %% [markdown]
# ### Function Questions/Answers

# %% [markdown]
# ### Theory Q/A

# %% [markdown]
# ### 1) What is the difference between a function and a method in Python?

# %% [markdown]
# #### > FUNCTION: It is a block of code that performs a specific task and is not tied to any object. We define it using the "def" keyword.
# ##### > EXAMPLE: def add(a, b):
#     return a + b
# result = add(3, 5)
# print(result) output=8
# #### > METHOD: IT is a function that is associated with an object and is called on that object. It is defined inside a class and usually takes self as the first parameter.
# ##### >EXAMPLE: class Calculator:
#     def add(self, a, b):
#         return a + b
# calc = Calculator()
# result = calc.add(3, 5)
# print(result)  output=8

# %% [markdown]
# ### 2)  Explain the concept of function arguments and parameters in Python.

# %% [markdown]
# #### > PARAMETER: They are the placeholders in the function definition.They define what kind of input the function expects.
# #### > ARGUMENTS: They are the actual values we pass to the function when calling it.
# ##### > EXAMPLE: def greet(name):
#     print("Hello,", name)
# greet("Neha")
# ##### Here "name" is Parameter and "neha" is Argument.

# %% [markdown]
# ### 3)  What are the different ways to define and call a function in Python?

# %% [markdown]
# #### > There are differnt ways to define and call a function in python and some of them are:
# ##### 1. Regular Function (with or without parameters):
# Example Define:def greet():
#     print("Hello!")
# Call: greet()
# ##### 2. Function with Parameters:
# Example Define: def greet(name):
#     print("Hello,", name)
#   Call: greet("Neha")
# ##### 3. Function with Default Parameters:
# Example Define: def greet(name="Guest"):
#     print("Hello,", name)
#   Call: greet()
# ##### 4. Function with Return Value:
# Example Define: def add(a, b):
#     return a + b
# Call: result = add(3, 5)
# print(result)

# %% [markdown]
# ### 4) What is the purpose of the `return` statement in a Python function?

# %% [markdown]
# #### > The return statement is used in a function to send back a result to the place where the function was called. It ends the function and returns data,Means we use return to get output from a function and store the result for later use.
# ##### >EXAMPLE: def add(a, b):
#     return a + b  # returns the sum
#
# result = add(3, 5)
# print(result) output=8

# %% [markdown]
# ### 5)  What are iterators in Python and how do they differ from iterables?

# %% [markdown]
# #### > ITERATOR: An iterator is an object that returns items one by one using the next() function.
# #### > ITERABLE: An iterable is any object that can be looped over.
# ##### > EXAMPLE: for fruit in fruits:
#     print(fruit)
#   Here fruits are Iterable

# %% [markdown]
# ### 6) Explain the concept of generators in Python and how they are defined.

# %% [markdown]
# #### > Generators are a special way to create iterators in Python using functions and uses "yield" keyword.They generate items one at a time, instead of storing the entire result in memory.
# ##### >EXAMPLE: def count_num(n):
#     i = 1
#     while i <= n:
#         yield i
#         i += 1
#   counter = count_num(2)
# print(next(counter))
# print(next(counter))

# %% [markdown]
# ### 7)  What are the advantages of using generators over regular functions?

# %% [markdown]
# #### > Advantages of Using Generators over Regular Functions are:
# ##### 1. Memory Efficiency
# ##### 2. Simpler Code for Iterators

# %% [markdown]
# ### 8)  What is a lambda function in Python and when is it typically used?

# %% [markdown]
# #### > A lambda function is a small, anonymous function defined with the keyword "lambda".It can take any number of arguments but can only have one expression.Its typically used When we need a small function for a short period
# ##### > EXAMPLE: number = lambda x: x * 2
# print(number(5)) output=10

# %% [markdown]
# ### 9) Explain the purpose and usage of the `map()` function in Python.

# %% [markdown]
# #### > The map() function applies a given function to every item in an iterable and returns an iterator with the results.The usage of map() function is to transform each element in a collection using a function and avoid writing loops manually for simple operations.
# ##### > EXAMPLE: numbers = [1, 2, 3, 4]
# num = map(lambda x: x * 2, numbers)
# print(list(num)) output=[2,4,6,8]

# %% [markdown]
# ### 10)  What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

# %% [markdown]
# #### > map(): Applies a given function to each item of an iterable and returns a map object (an iterator) with the results.
# ##### > EXAMPLE: numbers = [1, 2, 3, 4]
# num = map(lambda x: x * 2, numbers) print(list(num)) output=[2,4,6,8]
# #### > reduce(): Applies a function cumulatively to the items of an iterable, reducing the iterable to a single value.
# ##### > EXAMPLE: from functools import reduce
# nums = [1, 2, 3, 4]
# product = reduce(lambda x, y: x * y, nums)
# print(product) output: 24
# #### > filter(): Filters items out of an iterable by applying a function that returns True or False. Only elements where the function returns True are kept.
# ##### >EXAMPLE: nums = [1, 2, 3, 4, 5, 6]
# evens = filter(lambda x: x % 2 == 0, nums)
# print(list(evens)) output: [2, 4, 6]

# %% [markdown]
# ### 11)  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# ![11)ANS.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Practical Q/A

# %% [markdown]
# ### 1)  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_even_numbers(numbers):
    even_sum = 0
    for num in numbers:
        if num % 2 == 0:
            even_sum += num
    return even_sum
my_list = [1, 2, 3, 4, 5, 6]
result = sum_even_numbers(my_list)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 12

# %% [markdown]
# ### 2) Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(text):
    return text[::-1]
input_str = "hello"
reversed_str = reverse_string(input_str)
print("Reversed string:", reversed_str)
# Out:
# Reversed string: olleh

# %% [markdown]
# ### 3)  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_numbers(numbers):
    return [num ** 2 for num in numbers]
my_list = [1, 2, 3, 4, 5]
squared_list = square_numbers(my_list)
print("Squared list:", squared_list)
# Out:
# Squared list: [1, 4, 9, 16, 25]

# %% [markdown]
# ### 4)  Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2 or n > 200:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True
num = 16
if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# 16 is not a prime number.

# %% [markdown]
# ### 5)  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
class FibonacciIterator:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.a
fib = FibonacciIterator(10)
for num in fib:
    print(num, end=" ")
# Out:
# 0 1 1 1 2 3 5 8 13 21

# %% [markdown]
# ### 6)  Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for i in range(max_exponent + 1):
        yield 2 ** i
for value in powers_of_two(5):
    print(value)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# ### 7)  Implement a generator function that reads a file line by line and yields each line as a string

# %%
def read_lines(lines):
    for line in lines:
        yield line.strip()
file_lines = [
    "Hello\n",
    "World\n",
    "Python is fun\n"
]
for line in read_lines(file_lines):
    print(line)
# Out:
# Hello
# World
# Python is fun

# %% [markdown]
# ### 8) Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
my_list = [(1, 3), (4, 1), (2, 2), (5, 0)]
sorted_list = sorted(my_list, key=lambda x: x[1])
print(sorted_list)
# Out:
# [(5, 0), (4, 1), (2, 2), (1, 3)]

# %% [markdown]
# ### 9) Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32
celsius_temps = [0, 20, 37, 100]
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))
print(fahrenheit_temps)
# Out:
# [32.0, 68.0, 98.6, 212.0]

# %% [markdown]
# ### 10) Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(s):
    vowels = "aeiouAEIOU"
    return ''.join(filter(lambda ch: ch not in vowels, s))
input_str = "Hello, World!"
result = remove_vowels(input_str)
print(result)
# Out:
# Hll, Wrld!

# %% [markdown]
# ### 11)  Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this: Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.Write a Python program using lambda and map.

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]
result = list(map(lambda x: (x[0], x[2]*x[3] + 10 if x[2]*x[3] < 100 else x[2]*x[3]), orders))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
